# %%
xlist=[2,3,4,5,6,7]
for i in range(len(xlist)):
    xlist[i]=xlist[i]+10
print(xlist)
# Out:
# [12, 13, 14, 15, 16, 17]

# %%
xlist=[2,3,4,5,6,7]
i=0
while i < len(xlist):
  print(xlist[i])
  i=i+1
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
xlist=[2,3,4,5,6,7]
for i in xlist:
  print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
xlist=[2,3,4,5,6,7]
sumxlist=0
for i in range(len(xlist)):
  sumxlist=sumxlist + xlist[i]
  print(sumxlist)
# Out:
# 2
# 5
# 9
# 14
# 20
# 27

# %%
xlist=[2,3,4,5,6,7]
sumxlist=0
for i in xlist:
  sumxlist = i
  print(sumxlist)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
xlist=[2,3,4,5,6,7]
sumxlist=[]
for i in xlist:
  sumxlist.append(i)
  print(sumxlist)
# Out:
# [2]
# [2, 3]
# [2, 3, 4]
# [2, 3, 4, 5]
# [2, 3, 4, 5, 6]
# [2, 3, 4, 5, 6, 7]

# %%
xlist=[2,3,4,5,6,7]
newlist=[]
for x in xlist:
    newlist.append(x)
print(newlist)
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
fruits=['apple','banana','cherry','kiwi','mango','pineapple','guava','soursop']
newfruits=[]
for x in fruits:
  if 'a' in x:
    newfruits.append(x)
print(newfruits)
# Out:
# ['apple', 'banana', 'mango', 'pineapple', 'guava']

# %%
customer_1={'firstname':'martins','lastname':'olokpo'}
customer_1['workplace address']= '45 akuro adoki avenue new road'
customer_1['salary']= 20000
print(customer_1)
# Out:
# {'firstname': 'martins', 'lastname': 'olokpo', 'workplace address': '45 akuro adoki avenue new road', 'salary': 20000}
